# %% [markdown]
# # Decision Tree Classification #

# %% [markdown]
# ## Codeyard ##

# %%
# library imports
import re
import pandas as pd
import matplotlib.pyplot as plt
from utils import SimpleDataProcessing as SDP
from sklearn.preprocessing import LabelEncoder as LE
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier as DTC, plot_tree as PT
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## Ops Execution ##

# %%
# initialize class with data
data = "~\\Desktop\\data\\finance\\synthetic_credit_risk_data_historical.csv"
processor = SDP(data)

# %%
# make sets, train, and eval
x_train, x_test, x_val, y_train, y_test, y_val = processor.process_data()
model = processor.make_and_train_tree(x_train, y_train)
processor.evaluate_model(model, x_test, y_test)
# Out:
# Accuracy score: 0.87852
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89     47988
#            1       1.00      0.77      0.87     52012
#
#     accuracy                           0.88    100000
#    macro avg       0.90      0.88      0.88    100000
# weighted avg       0.90      0.88      0.88    100000

# %%
# plot tree
processor.plot_tree(model, x_train)
